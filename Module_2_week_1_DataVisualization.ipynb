# %%
import pandas as pd

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__deprecated_num_index_names', '__dir__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_is_numpy_dev', '_libs', '_testing', '_typing', '_version', 'annotations', 'api', 'array', 'arrays', '
# ...

# %%
[i for i in dir(pd)]
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
who = pd.read_csv("E:\Datavisualization_classes\WHO.csv")

# %%
print(who)
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# ...

# %%
print(type(who))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
who.ndim
# Out:
# 2

# %%
who
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# ...

# %%
who.head()
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
who["Cumulative_cases"].ndim
# Out:
# 1

# %%
who["Cumulative_cases"]
# Out:
# 0            1
# 1            1
# 2            4
# 3            4
# 4            4
#          ...
# 31871    63269
# 31872       24
# 31873    48826
# 31874       52
# 31875     9009
# Name: Cumulative_cases, Length: 31876, dtype: int64

# %%
who.columns
# Out:
# Index(['Date_reported', 'Country', 'New_cases', 'Cumulative_cases',
#        'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
who.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  object
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
who.shape
# Out:
# (31876, 6)

# %%
pd.to_datetime(who["Date_reported"])
# Out:
# 0       2020-01-04
# 1       2020-01-05
# 2       2020-01-06
# 3       2020-01-07
# 4       2020-01-08
#            ...
# 31871   2020-07-31
# 31872   2020-07-31
# 31873   2020-07-31
# 31874   2020-07-31
# 31875   2020-07-31
# Name: Date_reported, Length: 31876, dtype: datetime64[ns]

# %%
who.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  object
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
who.Country.unique()
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia', 'Australia', 'Canada', 'Sri Lanka',
#        'Cambodia', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
#        'India', 'Philippines', 'Sweden', 'Russian Federation',
#        'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Egypt',
#        'Iran (Islamic Republic of)', 'Israel', 'Lebanon', 'Oman',
#        'Bahrain', 'Switzerland', 'Iraq', 'Afghanistan', 'Kuwait',
#        'Algeria', 'Austria', 'Romania', 'Norway', 'North Macedonia',
#        'Croatia', 'Georgia', 'Pakistan', 'Brazil', 'Denmark', 'Greece',
#        'Estonia', 'Nigeria', 'Lithuania', 'New Zealand', 'Mexico',
#        'Netherlands', 'San Marino', 'Ecuador', 'Monaco', 'Qatar',
#        'Azerbaijan', 'Belarus', 'Armenia', 'Czechia', 'Ireland',
#        'Iceland', 'Luxembourg', 'Morocco', 'Saint Barthélemy', 'Portugal',
# ...

# %%
who.Country == "Italy"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31871    False
# 31872    False
# 31873    False
# 31874    False
# 31875    False
# Name: Country, Length: 31876, dtype: bool

# %%
bol = who.Country == "Italy"

# %%
italy = who[bol]

# %%
print(italy)
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# ...

# %%
Pakistan = who[who.Country == "Pakistan"]
Pakistan
# Out:
#       Date_reported   Country  New_cases  Cumulative_cases  New_deaths  \
# 898      2020-02-26  Pakistan          6                 6           0
# 910      2020-02-27  Pakistan          0                 6           0
# 995      2020-02-28  Pakistan          0                 6           0
# 1022     2020-02-29  Pakistan          2                 8           0
# 1113     2020-03-01  Pakistan          0                 8           0
# ...             ...       ...        ...               ...         ...
# 30882    2020-07-27  Pakistan       1176            274289          20
# 31051    2020-07-28  Pakistan        936            275225          23
# 31392    2020-07-29  Pakistan       1063            276288          27
# 31586    2020-07-30  Pakistan       1114            277402          32
# 31831    2020-07-31  Pakistan        903            278305          27
#
#        Cumulative_deaths
# 898                    0
# 910                    0
# 995                    0
# ...

# %%
print(Pakistan)
# Out:
#       Date_reported   Country  New_cases  Cumulative_cases  New_deaths  \
# 898      2020-02-26  Pakistan          6                 6           0
# 910      2020-02-27  Pakistan          0                 6           0
# 995      2020-02-28  Pakistan          0                 6           0
# 1022     2020-02-29  Pakistan          2                 8           0
# 1113     2020-03-01  Pakistan          0                 8           0
# ...             ...       ...        ...               ...         ...
# 30882    2020-07-27  Pakistan       1176            274289          20
# 31051    2020-07-28  Pakistan        936            275225          23
# 31392    2020-07-29  Pakistan       1063            276288          27
# 31586    2020-07-30  Pakistan       1114            277402          32
# 31831    2020-07-31  Pakistan        903            278305          27
#
#        Cumulative_deaths
# 898                    0
# 910                    0
# 995                    0
# ...

# %%
who.head(50)
# Out:
#    Date_reported                   Country  New_cases  Cumulative_cases  \
# 0     2020-01-04                     China          1                 1
# 1     2020-01-05                     China          0                 1
# 2     2020-01-06                     China          3                 4
# 3     2020-01-07                     China          0                 4
# 4     2020-01-08                     China          0                 4
# 5     2020-01-09                     China          0                 4
# 6     2020-01-10                     China          0                 4
# 7     2020-01-11                     China         41                45
# 8     2020-01-12                     China          0                45
# 9     2020-01-13                  Thailand          5                 5
# 10    2020-01-13                     China          0                45
# 11    2020-01-14                     China          0                45
# ...
